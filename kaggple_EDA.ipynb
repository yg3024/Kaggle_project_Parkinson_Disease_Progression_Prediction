# %% [markdown]
# ### Kaggle_project_Parkinson_Disease_Progression EDA
# Short term goal:finsh project data EDA within March
# Final deadline: May 18, 2023

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm
import scipy.stats
from math import sqrt

# %%
peptides = pd.read_csv('/Users/yijun/Documents/Projects/Kaggle_project_Parkinson_Disease_Progression/ori_data/train_peptides.csv')
peptides
# Out:
#          visit_id  visit_month  patient_id UniProt  \
# 0            55_0            0          55  O00391
# 1            55_0            0          55  O00533
# 2            55_0            0          55  O00533
# 3            55_0            0          55  O00533
# 4            55_0            0          55  O00533
# ...           ...          ...         ...     ...
# 981829  58648_108          108       58648  Q9UHG2
# 981830  58648_108          108       58648  Q9UKV8
# 981831  58648_108          108       58648  Q9Y646
# 981832  58648_108          108       58648  Q9Y6R7
# 981833  58648_108          108       58648  Q9Y6R7
#
#                                        Peptide  PeptideAbundance
# 0                                NEQEQPLGQWHLS          11254.30
# 1                                  GNPEPTFSWTK         102060.00
# 2                              IEIPSSVQQVPTIIK         174185.00
# 3       KPQSAVYSTGSNGILLC(UniMod_4)EAEGEPQPTIK          27278.90
# ...
